# %% [markdown]
# # Chapter 2 Assignment
#
# Please fill in blanks in the *Answer* sections of this notebook. To check your answer for a problem, run the Setup, Answer, and Result sections. DO NOT MODIFY SETUP OR RESULT CELLS. See the [README](https://github.com/mortonne/datascipsych) for instructions on setting up a Python environment to run this notebook.
#
# Write your answers for each problem. Then restart the kernel, run all cells, and then save the notebook. Upload your notebook to Canvas.
#
# If you get stuck, read through the other notebooks in this directory, ask us for help in class, or ask other students for help in class or on the weekly discussion board.

# %% [markdown]
# ## Problem: creating a function (2 points)
# Write a function called `mult_pi` that takes in some number, multiplies it by pi, and returns the result (1 point). Hint: you will need to import a module. Include a docstring that says "Multiply by pi." (1 point).

# %% [markdown]
# ### Setup

# %%
mult_pi = None

# %% [markdown]
# ### Answer

# %%
# your code here

# %% [markdown]
# ### Result

# %%
if mult_pi is not None:
    # this should display your variables
    print(mult_pi(7))
    help(mult_pi)

    # this should not throw any errors
    assert round(mult_pi(7), 2) == 21.99

# %% [markdown]
# ## Problem: function inputs (2 points)
#
# Create a function called `shift_and_scale` that takes a number `x` and calculates $\text{shift} + x * \text{scale}$ (0.5 points). The `shift` input should be a keyword argument that defaults to 0 (0.5 points), and the `scale` input should be a keyword argument that defaults to 1 (0.5 points). Add a docstring that says "Scale and add a shift to a number." (0.5 points).

# %% [markdown]
# ### Setup

# %%
shift_and_scale = None

# %% [markdown]
# ### Answer

# %%
# your code here

# %% [markdown]
# ### Result

# %%
if shift_and_scale is not None:
    # this should print your variables
    x = 1.5
    print(shift_and_scale(x))
    print(shift_and_scale(x, shift=-1, scale=2))
    help(shift_and_scale)

    # this should not throw any errors
    assert shift_and_scale(x) == 1.5
    assert shift_and_scale(x, shift=-1, scale=2) == 2

# %% [markdown]
# ## Problem: function outputs (2 points)
#
# Create a function called `subject_stats` that takes a list of numeric identifiers for subjects in a study and returns statistics about them, including the number of subjects, the lowest subject number, and the highest subject number (0.5 points each). Your function should return three outputs. Hint: you can use the `len`, `min`, and `max` functions. Include a docstring that says "Get number of subjects, lowest number, and highest number." (0.5 points).

# %% [markdown]
# ### Setup

# %%
subjects = [3, 4, 5, 7, 8, 10]
subject_stats = None

# %% [markdown]
# ### Answer

# %%
# your code here

# %% [markdown]
# ### Result

# %%
if subject_stats is not None:
    # this should print your variables
    print(subject_stats(subjects))
    help(subject_stats)

    # this should not throw any errors    
    n, subj_min, subj_max = subject_stats(subjects)
    assert n == 6
    assert subj_min == 3
    assert subj_max == 10

# %% [markdown]
# ## Problem: if/else statements (2 points)
# Create a function called `isodd` that uses an `if/else` statement (0.5 points) to test whether a number `x` is odd and return `True` if it is odd (0.5 points) and `False` otherwise (0.5 points). To do this, you can use the modulo operator `%`. If `x % 2 == 0`, then `x` is an even number. If `x % 2 == 1`, then `x` is an odd number. Include a docstring that says "Test if a number is odd." (0.5 points).

# %% [markdown]
# ### Setup

# %%
isodd = None

# %% [markdown]
# ### Answer

# %%
# your code here

# %% [markdown]
# ### Result

# %%
if isodd is not None:
    # this should print your variables
    print(isodd(1))
    print(isodd(2))
    help(isodd)

    # this should not throw any errors
    assert isodd(1) == True
    assert isodd(2) == False

# %% [markdown]
# ## Problem: comparison operators (2 points)
#
# Write a function called `included` that takes a number called `score` and returns `True` or `False` (0.5 points). Your function should return `True` if the score is greater than or equal to 10 (0.5 points) and `False` otherwise (0.5 points). Include a docstring that says "Test if a score should be included." (0.5 points).

# %% [markdown]
# ### Setup

# %%
included = None

# %% [markdown]
# ### Answer

# %%
# your code here

# %% [markdown]
# ### Result

# %%
if included is not None:
    # this should display your variables
    print(included(5))
    print(included(10))
    print(included(12))
    help(included)

    # this should not throw any errors
    assert included(5) == False
    assert included(10) == True
    assert included(12) == True

# %% [markdown]
# ## Problem: accessing data (2 points)
#
# Write a function called `get_score` that takes a subject identifier called `subject_id`, a dictionary called `subject_scores`, and a list of excluded subjects called `excluded_subjects` (0.5 points). Example inputs are defined below. Your function should return either the score for the subject, if they are not in the list of excluded subjects (0.5 points), or `None`, if they are in the list of excluded subjects (0.5 points). You can use `subject_id not in excluded_subjects` to test if a given subject identifier is not in the list of excluded identifiers. Include a docstring that says "Get the score for a subject if they are included." (0.5 points).

# %% [markdown]
# ### Setup

# %%
get_score = None
subject_id = "01"
subject_scores = {"01": 5, "02": 7, "03": 3, "04": 10}
excluded_subjects = ["01", "03"]

# %% [markdown]
# ### Answer

# %%
# your code here

# %% [markdown]
# ### Result

# %%
if get_score is not None:
    # this should display your variables
    s01 = get_score("01", subject_scores, excluded_subjects)
    s02 = get_score("02", subject_scores, excluded_subjects)
    print(s01)
    print(s02)
    help(get_score)

    # this should not throw any errors
    assert s01 is None
    assert s02 == 7

# %% [markdown]
# ## Problem (graduate students): using functions (2 points)
#
# ### Write a function to calculate the mean (1 point)
#
# Write a function called `rt_mean` that takes in a list of response times (in seconds) and calculates the mean (0.5 points). The mean is defined as the sum divided by the number of samples (hint: try using the built-in `sum` and `len` functions). Include a docstring that describes what the function does, using a short, declarative statement (0.5 points)
#
# ### Call a function with different inputs (1 point)
#
# Use your function to calculate mean response time in condition 1 and assign it to a variable named `mean1` (0.5 points). Use your function again to calculate mean response time in condition 2 and assign it to a variable named `mean2` (0.5 points).

# %% [markdown]
# ### Setup

# %%
response_times1 = [1.5, 2.1, 2.3, 1.8]  # response times (s) in condition 1
response_times2 = [1.7, 4.1, 1.3, 1.5]  # response times (s) in condition 2
rt_mean = None
mean1 = None
mean2 = None

# %% [markdown]
# ### Answer

# %%
# your code here

# %% [markdown]
# ### Result

# %%
vars = [rt_mean, mean1, mean2]
if all([v is not None for v in vars]):
    # this should display your variables
    print(mean1)
    print(mean2)
    help(rt_mean)

    # this should not throw any errors
    assert rt_mean(response_times1) == 1.925
    assert rt_mean(response_times2) == 2.15

# %% [markdown]
# ## Problem (graduate students): printing instructions (2 points)
# Say that we have three conditions in an experiment, and each one has different instructions for what the participant should do when a word shows up on screen. Define a function called `instruct` that uses an `if/elif/else` statement to display (using `print`) the correct instructions depending on the condition. If the condition doesn't match condition 1, 2, or 3, raise an exception instead, with a `ValueError`.

# %% [markdown]
# ### Setup

# %%
instruct1 = "Read the word out loud."  # instructions for condition 1
instruct2 = "Read the word silently."  # instructions for condition 2
instruct3 = "Type the word."  # instructions for condition 3
error_message = "Error: condition code unknown."  # raise exception if condition not 1, 2, or 3
instruct = None

# %% [markdown]
# ### Answer

# %%
# your code here

# %% [markdown]
# ### Result

# %%
if instruct is not None:
    # this should display your instructions
    instruct(1)
    instruct(2)
    instruct(3)

    # this should not throw an error
    try:
        instruct(-1)
    except ValueError as err:
        assert err.args[0] == error_message

# %% [markdown]
# ## Problem (graduate students): functional programming (2 points)
#
# Read about the built-in functions `map` and `filter` in the [Python tutorial](https://docs.python.org/3/howto/functional.html#built-in-functions). The `map` and `filter` functions can be used to apply a given function to each element in a list, to either apply an operation to each element (`map`) or to get only the elements that are marked as included by a function (`filter`).
#
# ### Use map to apply a function to each element of a list (1 point)
#
# Given the list `scores` (defined below), use the `map` function with `math.ceil` to round up each score. Convert the result to a list using the `list` function and assign that list to a variable named `scores_ceil`.
#
# ### Use filter to select elements of a list (1 point)
#
# Define a function called `check_score` that takes one variable `x` and returns `True` if $x >= 5$ and `False` otherwise (0.5 points). Use your function with the `filter` function to take the list `scores` and get only the scores that are greater than or equal to 5. Convert the result to a list using the `list` function and assign that list to a variable named `scores_included`.

# %% [markdown]
# ### Setup

# %%
scores = [6.2, 1.5, 2.75, 3.1, 4.3, 6.75]
scores_ceil = None
check_score = None
scores_included = None

# %% [markdown]
# ### Answer

# %%
# your code here

# %% [markdown]
# ### Result

# %%
vars = [scores_ceil, check_score, scores_included]
if all([v is not None for v in vars]):
    # this should display your variables
    print(scores_ceil)
    print(scores_included)

    # this should not throw any errors
    assert scores_ceil == [7, 2, 3, 4, 5, 7]
    assert check_score(4) == False
    assert check_score(5) == True
    assert scores_included == [6.2, 6.75]

# %% [markdown]
# ## Problem (graduate students): lambda functions (2 points)
#
# Read about *lambda functions* in the [Python tutorial](https://docs.python.org/3/howto/functional.html#small-functions-and-the-lambda-expression). Lambda functions, which are also known as *anonymous functions*, are defined in one line and do not have a name. They can be useful when you need to define a simple function that can be succinctly defined in one line of code. For example, `lambda x: x + 2` defines a function that takes one input `x` and returns `x + 2`. It works the same as the `add_two` function below, which is defined the usual way using a `def` statement:
#
# ```python
# def add_two(x):
#     return x + 2
# ```
#
# Use a lambda function with `filter` to take the list `subjects` (defined below) and get a list with only subjects that are not in the list `excluded`. Remember, you can use `x not in y` to test if some item `x` is not in the list `y`. Convert the result to a list using the `list` function and assign the list to a variable called `included` (1 point). Do all of this in one line of code (1 point).

# %% [markdown]
# ### Setup

# %%
subjects = [1, 2, 3, 4, 5]
excluded = [2, 5]
included = None

# %% [markdown]
# ### Answer

# %%
# your code here

# %% [markdown]
# ### Result

# %%
if included is not None:
    # this should display your variable
    print(included)

    # this should not throw any errors
    assert included == [1, 3, 4]
