# %% [markdown]
# # Chapter 3 Assignment (NOT FINALIZED)
#
# Please fill in blanks in the *Answer* sections of this notebook. To check your answer for a problem, run the Setup, Answer, and Result sections. DO NOT MODIFY SETUP OR RESULT CELLS. See the [README](https://github.com/mortonne/datascipsych) for instructions on setting up a Python environment to run this notebook.
#
# Write your answers for each problem. Then restart the kernel, run all cells, and then save the notebook. Upload your notebook to Canvas.
#
# If you get stuck, read through the other notebooks in this directory, ask us for help in class, or ask other students for help in class or on the weekly discussion board.

# %% [markdown]
# ## Problem: using a for loop to calculate a total (2 points)
#
# Use a `for` loop to calculate the sum of the list `subject_scores` and assign the result to a variable named `total`.

# %% [markdown]
# ### Setup

# %%
subject_scores = [2, 5, 7, 3, 4, 9, 10, 2, 8]
total = None

# %% [markdown]
# ### Answer

# %%
# your code here

# %% [markdown]
# ### Result

# %%
if total is not None:
    # this should display your variable
    print(total)

    # this should not throw any errors
    assert total == 50

# %% [markdown]
# ## Problem: using a function to calculate a total (2 points)
#
# ### Using the built-in sum function (0.5 points)
#
# Use the built-in `sum` function to calculate the sum of the list of numbers in `subject_scores`. Assign the result to a variable named `total`.
#
# ### Writing your own sum function (1.5 points)
#
# Write a function called `my_sum` that takes in a list of numbers and uses a `for` loop to calculate and return their sum (0.5 points). Do NOT use the `sum` function in your `my_sum` function. Include a docstring that says "Calculate the sum of a list of numbers." (0.5 points). Use your function to calculate the sum of the variable `subject_scores`, and assign the result to a variable named `my_total` (0.5 points).

# %% [markdown]
# ### Setup

# %%
subject_scores = [2, 5, 7, 3, 4, 9, 10, 2, 8]
total = None
my_sum = None
my_total = None

# %% [markdown]
# ### Answer

# %%
# your code here

# %% [markdown]
# ### Result

# %%
vars = [total, my_sum, my_total]
if all([v is not None for v in vars]):
    # this should display your variables
    print(total)
    print(my_total)
    help(my_sum)

    # this should not throw any errors
    assert total == 50
    assert my_total == 50

# %% [markdown]
# ## Problem: using for loops and if statements (2 points)
#
# Create a function called `sum_small` that uses a `for` loop and an `if` statement to take a list of numbers and calculate the sum of the numbers (1 point) that are less than ten (0.5 points). For example, if the numbers are 3, 12, 8, 4, 10, 0, then only the numbers 3, 8, 4, 0 should be summed, and the output should be 15. Include a docstring that says "Sum numbers that are less than ten." (0.5 points).

# %% [markdown]
# ### Setup

# %%
numbers = [3, 12, 8, 4, 10, 0]
sum_small = None

# %% [markdown]
# ### Answer

# %%
# your code here

# %% [markdown]
# ### Result

# %%
if sum_small is not None:
    # this should display your variables
    print(sum_small(numbers))
    help(sum_small)

    # this should not throw any errors
    assert sum_small(numbers) == 15

# %% [markdown]
# ## Problem: looping over two lists (2 points)
#
# Below, two lists are defined: `subject_ages`, which lists the age of each subject in a study in years, and `subject_scores`, which lists the corresponding scores on a cognitive test for each subject. Say that we want to calculate the total for subjects who are less than 30 years old.
#
# Use a `for` loop with an `if` statement to calculate the sum of scores in `subject_scores`, but only including subjects whose age (listed in `subject_ages`) is less than 30. Assign the result to a variable called `younger_adult_total`.

# %% [markdown]
# ### Setup

# %%
subject_ages = [23, 30, 35, 55, 25, 17, 18, 42, 29]
subject_scores = [2, 5, 7, 3, 4, 9, 10, 2, 8]
younger_adult_total = None

# %% [markdown]
# ### Answer

# %%
# your code here

# %% [markdown]
# ### Result

# %%
if younger_adult_total is not None:
    # this should display your variable
    print(younger_adult_total)

    # this should not throw any errors
    assert younger_adult_total == 33

# %% [markdown]
# ## Problem: analyzing conditions (2 points)
#
# Say that you have data for 8 trials in a study. Each trial was in one of two conditions (condition 1 or condition 2). On each trial, the participant either answered correctly (coded as a 1) or incorrectly (coded as a 0). The condition code is in the `condition` variable below, and the accuracy on each corresponding trial is in the `correct` variable. We want to know how often trials in condition 2 were answered correctly.
#
# Use a `for` loop with an `if` statement to calculate the total score for condition 2 and assign it to a variable named `total2` (1 point). Use the same loop to also calculate the total number of trials in condition 2 and assign it to a variable named `n2` (0.5 points). Finally, use your `total2` and `n2` variables to calculate fraction correct (that is, the number of correct trials in condition 2 divided by the number of trials in condition 2) and assign it to a variable named `accuracy2` (0.5 points).

# %% [markdown]
# ### Setup

# %%
condition = [1, 1, 2, 2, 1, 1, 2, 2]  # condition label for each trial
correct   = [0, 1, 1, 1, 0, 0, 1, 0]  # 1 for correct, 0 for incorrect
total2 = None
n2 = None
accuracy2 = None

# %% [markdown]
# ### Answer

# %%
# your code here

# %% [markdown]
# ### Result

# %%
vars = [total2, n2, accuracy2]
if all([v is not None for v in vars]):
    # this should display your variables
    print(total2)
    print(n2)
    print(accuracy2)

    # this should not throw any errors
    assert total2 == 3
    assert n2 == 4
    assert accuracy2 == 0.75

# %% [markdown]
# ## Problem: writing an analysis function (2 points)
#
# Say that you have data for 12 trials in a study. Each trial was in one of three conditions (condition A, B, or C). On each trial, the participant either answered correctly (coded as a 1) or incorrectly (coded as a 0). We want to write a function that can be used to calculate accuracy for different conditions, depending on the inputs to the function.
#
# Write a function called `condition_accuracy` that takes a list of trial condition codes (such as the `condition_code` list below), a list indicating whether each trial was correct or incorrect (such as the `trial_correct` list below), and a condition to analyze (such as `"A"` or `"B"`). Your function should return the accuracy in the indicated condition (that is, the number of correct trials in that condition divided by the number of trials in that condition; 1 point). Include a docstring that says "Calculate accuracy in one condition." (0.5 points). Use your function with the `condition_code` and `trial_correct` data (defined below) to calculate accuracy in condition C and assign it to a variable named `accuracy_C` (0.5 points).

# %%
condition_code = ["A", "B", "C", "A", "B", "C", "A", "B", "C", "A", "B", "C"]
trial_correct  = [ 0,   0,   1,   1,   1,   1,   1,   0,   1,   1,   1,   0 ]
condition_accuracy = None
accuracy_C = None

# %% [markdown]
# ### Answer

# %%
# your code here

# %% [markdown]
# ### Result

# %%
vars = [condition_accuracy, accuracy_C]
if all([v is not None for v in vars]):
    # this should display your variables
    print(accuracy_C)
    help(condition_accuracy)

    # this should not throw any errors
    assert condition_accuracy(condition_code, trial_correct, "A") == 0.75
    assert condition_accuracy(condition_code, trial_correct, "B") == 0.5
    assert condition_accuracy(condition_code, trial_correct, "C") == 0.75
    assert accuracy_C == 0.75

# %% [markdown]
# ## Problem (graduate students): using other operations in for loops (2 points)
#
# The *factorial* of a number $n$ is defined as $n! = n * (n - 1) * (n - 2) * ... * 1$.
#
# ### Using the math module factorial function (0.5 points)
#
# Use the `factorial` function of the `math` module to calculate $6!$ and assign it to a variable named `f6`.
#
# ### Writing your own factorial function (1.5 points)
#
# Write your own function, called `my_factorial`, to calculate the factorial of any positive integer $n$ (0.5 points). Include a docstring that says "Calculate n!." (0.5 points). Do NOT use the `factorial` function. Hint: use a `for` loop with `range` to iterate over a range of integers. Use your function to calculate $6!$ and assign it to a variable named `my_f6`.

# %% [markdown]
# ### Setup

# %%
f6 = None
my_factorial = None
my_f6 = None

# %% [markdown]
# ### Answer

# %%
# your code here

# %% [markdown]
# ### Result

# %%
vars = [f6, my_factorial, my_f6]
if all([v is not None for v in vars]):
    # this should display your variables
    print(f6)
    print(my_f6)
    help(my_factorial)

    # this should not throw any errors
    assert f6 == 720
    assert my_f6 == 720

# %% [markdown]
# ## Problem (graduate students): using list comprehensions (2 points)
# Say that you have a list of subject numbers 1, 2, 101, and 102, and you need to make a list of full subject identifiers `"sub-001"`, `"sub-002"`, `"sub-101"`, `"sub-102"`. Use a list comprehension with an f-string expression to create the subject identifiers from the numbers. Assign the result to a variable called `subject_ids`.
#
# Hint: you can format a number with zero-padding to three digits using the `:03d` format specifier in your f-string.

# %% [markdown]
# ### Setup

# %%
subject_numbers = [1, 2, 101, 102]
subject_ids = None

# %% [markdown]
# ### Answer

# %%
# your code here

# %% [markdown]
# ### Result

# %%
if subject_ids is not None:
    # this should display your variable
    print(subject_ids)

    # this should not throw any errors
    assert subject_ids == ["sub-001", "sub-002", "sub-101", "sub-102"]

# %% [markdown]
# ## Problem (graduate students): throwing exceptions (4 points)
#
# ### Write a function to analyze mean response time (2 points)
#
# Write a function called `condition_rt` that takes a list indicating the condition code for a set of trials, a list with the corresponding response times, and the condition to be analyzed (for example, 1 or 2), with the inputs named `trial_condition`, `response_time`, and `condition` (0.5 points). Your function should return the mean response time for the condition of interest (1 point). Include a docstring that briefly summarizes what the function does using a simple imperative sentence (0.5 points).
#
# ### Check for valid inputs (2 points)
#
# Note that, if the requested condition to analyze is not found in the list of trials, the mean response time for that condition cannot be calculated. Modify your function so that, if the requested condition is not present in the `trial_condition` input, a `ValueError` will be raised (1 point) with the message "No trials of condition {condition}.", with the "{condition}" replaced with the condition that was passed as input (1 point).

# %% [markdown]
# ### Setup

# %%
trial_condition = [1, 1, 1, 1, 2, 2, 2, 2]
response_time = [2.3, 4.2, 3.5, 3.1, 4.8, 6.2, 5.3, 4.5]
condition_rt = None

# %% [markdown]
# ### Answer

# %%
# your code here

# %% [markdown]
# ### Result

# %%
if condition_rt is not None:
    # this should display your variables
    help(condition_rt)

    # this should not throw any errors
    assert condition_rt(trial_condition, response_time, 1) == 3.275
    assert condition_rt(trial_condition, response_time, 2) == 5.2
    try:
        condition_rt(trial_condition, response_time, 3)
    except ValueError as err:
        assert err.args[0] == "No trials of condition 3."
