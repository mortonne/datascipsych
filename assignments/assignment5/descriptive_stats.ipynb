# %% [markdown]
# # Descriptive statistics
# NumPy arrays can be used for data analysis, using NumPy and SciPy functions and Matplotlib plots.

# %% [markdown]
# ## Random data generation
# We can use various NumPy functions to generate random data. We'll use this for some examples.

# %%
rng = np.random.default_rng(42)
h = plt.hist(rng.normal(loc=10, scale=2, size=10000))

# %% [markdown]
# ## Measures of central tendency

# %% [markdown]
# ## Measures of spread

# %% [markdown]
# ## Simple plot types

# %% [markdown]
# ## Anatomy of a figure
